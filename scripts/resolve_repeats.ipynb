# %%
import pandas as pd
df = pd.read_csv('data/to_use/survey_features_wide.csv', encoding='utf-8-sig')
# Out:
# /Users/sonia/Documents/SYEP

# %%
df_sorted = df.sort_values(by='Year', ascending=True)
df_earliest = df_sorted.drop_duplicates(subset=['Participant.Unique.ID'], keep='first')

# %%
df_earliest.shape
# Out:
# (8209, 21)

# %%
df_earliest.to_csv('data/to_use/survey_features_wide.csv', index=False)

# %%
print(df_earliest['Year'].value_counts(normalize=True)*100)
# Out:
# Year
# 2022    30.844195
# 2024    29.723474
# 2023    20.550615
# 2025    18.881715
# Name: proportion, dtype: float64

# %%
print(df['Year'].value_counts(normalize=True)*100)
# Out:
# Year
# 2024    30.601216
# 2022    28.507093
# 2023    20.580950
# 2025    20.310741
# Name: proportion, dtype: float64

# %%
df_earliest.to_csv('data/to_use/survey_features_earliest_wide.csv', index=False)
